# %%
import torch

# %%
x = torch.tensor([[5, 2, 3],[9, 3, 1]])
x
# Out:
# tensor([[5, 2, 3],
#         [9, 3, 1]])

# %%
x[1].sort().indices
# Out:
# tensor([2, 1, 0])

# %%
x[0,x[1].sort().indices]
# Out:
# tensor([3, 2, 5])
